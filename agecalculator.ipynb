# %%
from tkinter import *
from tkinter import messagebox 
from datetime import date
today=date.today()
def clearAll() : 
    dayField.delete(0, END) 
    monthField.delete(0, END) 
    yearField.delete(0, END) 
    givenDayField.delete(0, END) 
    givenMonthField.delete(0, END) 
    givenYearField.delete(0, END) 
    rsltDayField.delete(0, END) 
    rsltMonthField.delete(0, END) 
    rsltYearField.delete(0, END) 
def rslt():
    rsltDayField.delete(0, END) 
    rsltMonthField.delete(0, END) 
    rsltYearField.delete(0, END)
def checkError() : 
    if (dayField.get() == "" or monthField.get() == "" 
        or yearField.get() == "" ) : 
        messagebox.showerror("Input Error") 
        clearAll() 
          
        return -1 
def calculateAge() : 
    value = checkError() 
    if value ==  -1 : 
        return
      
    else : 
        birth_day = int(dayField.get()) 
        birth_month = int(monthField.get()) 
        birth_year = int(yearField.get()) 
        given_day = int(today.day) 
        given_month = int(today.month) 
        given_year = int(today.year) 
        month =[31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31] 
        if (birth_day > given_day): 
            given_month = given_month - 1
            given_day = given_day + month[birth_month-1]  
        if (birth_month > given_month): 
            given_year = given_year - 1
            given_month = given_month + 12  
        calculated_day = given_day - birth_day;  
        calculated_month = given_month - birth_month;  
        calculated_year = given_year - birth_year; 
        rsltDayField.insert(10, str(calculated_day)) 
        rsltMonthField.insert(10, str(calculated_month)) 
        rsltYearField.insert(10, str(calculated_year)) 
if __name__ == "__main__" : 
    gui = Tk()    
    gui.configure(background = "light blue") 
    gui.title("Age Calculator") 
    gui.geometry("450x200") 
    dob = Label(gui, text = "Date Of Birth", bg = "yellow") 
    rs=Label(gui,text="Your Current Age",bg="yellow")
    givenDate = Label(gui, text = "Given Date", bg = "blue") 
    day = Label(gui, text = "Day", bg = "light blue") 
    month = Label(gui, text = "Month", bg = "light blue")  
    year = Label(gui, text = "Year", bg = "light blue") 
    rsltYear = Label(gui, text = "Years", bg = "light blue") 
    rsltMonth = Label(gui, text = "Months", bg = "light blue")  
    rsltDay = Label(gui, text = "Days", bg = "light blue") 
    resultantAge= Label(gui,bg="light blue")
    resultantAge.grid(row=4,column=6)
    resultantAge = Button(gui, text = "Resultant Age", fg = "Black", bg = "light green", command = calculateAge) 
    clearAllEntry = Button(gui, text = "Clear All", fg = "Black", bg = "light green", command = clearAll)   
    dayField = Entry(gui) 
    monthField = Entry(gui) 
    yearField = Entry(gui) 
      
    givenDayField = Entry(gui) 
    givenMonthField = Entry(gui) 
    givenYearField = Entry(gui) 
      
    rsltYearField = Entry(gui) 
    rsltMonthField = Entry(gui) 
    rsltDayField = Entry(gui)  
    dob.grid(row = 0, column = 1) 
    rs.grid(row=0,column =7)
      
    day.grid(row = 1, column = 0) 
    dayField.grid(row = 1, column = 1) 
      
    month.grid(row = 2, column = 0) 
    monthField.grid(row = 2, column = 1) 
      
    year.grid(row = 3, column = 0) 
    yearField.grid(row = 3, column = 1) 
      
      
    resultantAge.grid(row = 6, column = 6) 
      
    rsltYear.grid(row = 1, column = 6) 
    rsltYearField.grid(row = 1, column = 7) 
      
    rsltMonth.grid(row = 2, column = 6) 
    rsltMonthField.grid(row = 2, column = 7) 
      
    rsltDay.grid(row = 3, column = 6) 
    rsltDayField.grid(row = 3, column = 7) 
  
    clearAllEntry.grid(row = 8, column = 6)
    exit=Button(gui,text="EXIT",command=gui.destroy,bg="pink")
    exit.grid(row=25,column=0)
    
    cleamdy=Button(gui,text="Clear R Y,M,D",command=rslt,bg="blue")
    cleamdy.grid(row=6,column=7)
    
    gui.iconbitmap(r'C:\Users\Hp\Desktop\Age calculator\agecal1.ico')

    gui.mainloop()

# %%
print("\U0001F606")
# Out:
# 😆
